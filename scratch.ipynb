# %%
import requests as re
import os
from api_constants import *

# %%
live_pos = URL_BASE + LIVE_POSITION

# %%
header = {
    'Cache-Control': "no-cache",
    'api_key': os.environ['WMATA_API_KEY']
}

# %%
response = re.get(live_pos, headers=header).json()

# %%
response
# Out:
# {'TrainPositions': [{'TrainId': '079',
#    'TrainNumber': '775',
#    'CarCount': 0,
#    'DirectionNum': 1,
#    'CircuitId': 3077,
#    'DestinationStationCode': None,
#    'LineCode': None,
#    'SecondsAtLocation': 41,
#    'ServiceType': 'NoPassengers'},
#   {'TrainId': '128',
#    'TrainNumber': '816',
#    'CarCount': 6,
#    'DirectionNum': 2,
#    'CircuitId': 1165,
#    'DestinationStationCode': None,
#    'LineCode': None,
#    'SecondsAtLocation': 41,
#    'ServiceType': 'NoPassengers'},
#   {'TrainId': '138',
#    'TrainNumber': '817',
#    'CarCount': 8,
#    'DirectionNum': 1,
#    'CircuitId': 2211,
#    'DestinationStationCode': None,
#    'LineCode': None,
#    'SecondsAtLocation': 2,
#    'ServiceType': 'NoPassengers'},
#   {'TrainId': '141',
#    'TrainNumber': '000',
#    'CarCount': 0,
#    'DirectionNum': 2,
#    'CircuitId': 1295,
#    'DestinationStationCode': None,
#    'LineCode': None,
#    'SecondsAtLocation': 2,
#    'ServiceType': 'Unknown'},
# ...
